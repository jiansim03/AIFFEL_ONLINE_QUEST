# %% [markdown]
# <a href="https://colab.research.google.com/github/jiansim03/AIFFEL_Online_Quest/blob/main/Quest01/Untitled0_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('he')
print('222')
print('333')
print('444')

print('사본저장')
